# %% [markdown]
# # Important DataFrame Methods

# %%
# !mamba install pandas
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 3.217 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + pandas                        3.0.1                         np22py313h9d9dc1e_0           emscripten-forge
# + python-tzdata                 2025.3                        pyhd8ed1ab_0                  conda-forge
# - pip                           25.3                          pyh145f28c_0                  conda-forge

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## value_counts

# %%
marks= pd.read_csv('Student_Marks.csv')
marks.value_counts()
# Out:
# number_courses  time_study  Marks
# 3               4.508       19.202    1
# 4               0.096       7.734     1
#                 3.133       13.811    1
# 6               7.909       53.018    1
# 8               7.811       55.299    1
#                                      ..
# 6               3.561       19.128    1
# 3               0.301       5.609     1
# 4               7.163       41.444    1
# 7               0.309       12.027    1
# 3               6.335       32.357    1
# Name: count, Length: 100, dtype: int64

# %%
bolly= pd.read_csv('BollywoodActorRanking.csv')
bolly.value_counts()
# Out:
# actorId  actorName         movieCount  ratingSum  normalizedMovieRank  googleHits  normalizedGoogleRank  normalizedRating
# 373      Aamir Khan        11          1170       9.44862              2460000     7.34283               10.00000            1
# 374      Shah Rukh Khan    23          2000       7.55009              2670000     7.88458               9.22674             1
# 375      Salman Khan       36          2340       5.40217              3490000     10.00000              9.20821             1
# 376      Katrina Kaif      17          1640       8.48082              2120000     6.46570               8.94852             1
# 377      Deepika Padukone  16          1080       5.64674              3000000     8.73591               8.62716             1
#                                                                                                                             ..
# ...

# %% [markdown]
# ## sort values

# %%
(bolly['ratingSum'].value_counts()+  bolly['actorId'].value_counts()).sort_values(ascending= False)
# Out:
# ratingSum
# 400     8.0
# 380     4.0
# 450     4.0
# 500     4.0
# 390     3.0
#        ...
# 2140    NaN
# 2200    NaN
# 2320    NaN
# 2340    NaN
# 2950    NaN
# Name: count, Length: 377, dtype: float64

# %%
bolly.sort_values('actorName')
# Out:
#      actorId          actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373         Aamir Khan          11       1170              9.44862
# 204      577     Aarti Chhabria           5        120              1.39130
# 170      543  Aashish Chaudhary           9        290              2.19565
# 278      651      Abhay Bhargav           4         80              1.00000
# 146      519         Abhay Deol          11        350              2.15613
# ..       ...                ...         ...        ...                  ...
# 229      602          Yash Tonk           5        160              2.17391
# 180      553     Yashpal Sharma          10        300              1.97826
# 297      670    Yuvika Chaudhry           5        100              1.00000
# 195      568      Zakir Hussain          10        210              1.09783
# 107      480         Zayed Khan          14        450              2.18789
#
#      googleHits  normalizedGoogleRank  normalizedRating
# ...

# %%
movies = pd.read_csv('BollywoodMovieDetail.csv')
movies_sorted = movies.sort_values(['title', 'releaseYear'], ascending=[True, False])
movies_sorted
# Out:
#          imdbId                        title  releaseYear  releaseDate  \
# 406   tt0473567                    ...Yahaan         2005  29 Jul 2005
# 732   tt1385824  13B: Fear Has a New Address         2009  06 Mar 2009
# 74    tt0313844                  16 December         2002  22 Mar 2002
# 700   tt1301698                         1920         2008  12 Sep 2008
# 1048  tt2222550           1920: Evil Returns         2012  02 Nov 2012
# ...         ...                          ...          ...          ...
# 789   tt1562872     Zindagi Na Milegi Dobara         2011  15 Jul 2011
# 1015  tt2164702            Zindagi Tere Naam         2012  16 Mar 2012
# 806   tt1605790                     Zokkomon         2011  22 Apr 2011
# 770   tt1479857       Zor Lagaa Ke... Haiya!         2009  12 Jun 2009
# 10    tt0255713                     Zubeidaa         2001  19 Jan 2001
#
#                               genre  \
# 406                         Romance
# 732        Drama | Horror | Mystery
# ...

# %% [markdown]
# ## Ranks

# %%
batsman= pd.read_csv('most_runs_in_ipl.csv')
batsman
# Out:
#     Rank           Player  Team  Runs   4s   6s  Mat  Innings Highest  100s  \
# 0      1      Virat Kohli   RCB  6624  578  218  223      215     113     5
# 1      2   Shikhar Dhawan  PBKS  6244  701  136  206      205    106*     2
# 2      3     David Warner    DC  5881  561  211  162      162     126     4
# 3      4     Rohit Sharma    MI  5879  519  240  227      222    109*     1
# 4      5     Suresh Raina   CSK  5528  506  203  205      200    100*     1
# ..   ...              ...   ...   ...  ...  ...  ...      ...     ...   ...
# 70    71     Deepak Hooda   LSG  1236   77   56   95       75      64     0
# 71    72  Ruturaj Gaikwad   CSK  1207  113   43   36       36    101*     1
# 72    73     Kedar Jadhav   SRH  1196  101   40   93       80      69     0
# 73    74     Irfan Pathan    GL  1139   87   37  103       82      60     0
# 74    75       Axar Patel    DC  1135   67   54  122       88      44     0
#
#     50s    Avg      SR
# 0    44  36.20  129.15
# ...

# %%
batsman['Innings'].rank()
batsman.head()
# Out:
#    Rank          Player  Team  Runs   4s   6s  Mat  Innings Highest  100s  \
# 0     1     Virat Kohli   RCB  6624  578  218  223      215     113     5
# 1     2  Shikhar Dhawan  PBKS  6244  701  136  206      205    106*     2
# 2     3    David Warner    DC  5881  561  211  162      162     126     4
# 3     4    Rohit Sharma    MI  5879  519  240  227      222    109*     1
# 4     5    Suresh Raina   CSK  5528  506  203  205      200    100*     1
#
#    50s    Avg      SR
# 0   44  36.20  129.15
# 1   47  35.08  126.35
# 2   54  42.01  140.69
# 3   40  30.30  129.89
# 4   39  32.52  136.76

# %% [markdown]
# ## Apply Method

# %%
points= pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)
points
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
    pt_A = row['1st point']
    pt_B = row['2nd point']

    return ((pt_A[0]-pt_B[0])**2 + (pt_A[1]-pt_B[1])**2) ** 0.5

# %%
points['distance'] = points.apply(euclidean, axis=1)
points
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000

# %% [markdown]
# ## Drop Method

# %% [markdown]
# ### drop on Series

# %%
temp = pd.Series([2,3,4,6,8,11,13,15])
temp
# Out:
# 0     2
# 1     3
# 2     4
# 3     6
# 4     8
# 5    11
# 6    13
# 7    15
# dtype: int64

# %%
temp.drop(2)
# Out:
# 0     2
# 1     3
# 3     6
# 4     8
# 5    11
# 6    13
# 7    15
# dtype: int64

# %%
temp.drop(index =[0,6])
# Out:
# 1     3
# 2     4
# 3     6
# 4     8
# 5    11
# 7    15
# dtype: int64

# %% [markdown]
# ### drop on DataFrame

# %%
marks
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
marks.drop(columns= ['Marks'])
# Out:
#     number_courses  time_study
# 0                3       4.508
# 1                4       0.096
# 2                4       3.133
# 3                6       7.909
# 4                8       7.811
# ..             ...         ...
# 95               6       3.561
# 96               3       0.301
# 97               4       7.163
# 98               7       0.309
# 99               3       6.335
#
# [100 rows x 2 columns]

# %%
marks.drop(index= [1, 3])
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 2                4       3.133  13.811
# 4                8       7.811  55.299
# 5                6       3.211  17.822
# 6                3       6.063  29.889
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [98 rows x 3 columns]

# %%
movies
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
movies.set_index('title').drop(index= ['Albela','Meri Biwi Ka Jawab Nahin'])
# Out:
#                                       imdbId  releaseYear  releaseDate  \
# title
# Lagaan: Once Upon a Time in India  tt0169102         2001  08 May 2002
# Hum Tumhare Hain Sanam             tt0222024         2002  24 May 2002
# One 2 Ka 4                         tt0227194         2001  30 Mar 2001
# Devdas                             tt0238936         2002  12 Jul 2002
# Aap Mujhe Achche Lagne Lage        tt0247911         2002  19 Apr 2002
# ...                                      ...          ...          ...
# Shuruaat Ka Interval               tt4121522         2014  15 Aug 2014
# Trip to Bhangarh                   tt4187650         2014  28 Aug 2014
# Zed Plus                           tt4190220         2014  28 Nov 2014
# Gollu aur Pappu                    tt4219300         2014  21 Nov 2014
# Zid                                tt4228746         2014  28 Nov 2014
#
#                                                          genre  \
# title
# ...

# %% [markdown]
# ## Dropna Method(for removing NaN values)

# %%
virat= pd.read_csv('Virat Kohli DataSet.csv')
virat
# Out:
#      Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0      12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 1      37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 2      25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 3      54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 4      31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ..    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127    45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 128    65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 129   122  105   8   5  116.19  3.0    caught     2      v England
# 130     8    5   2   0  160.00  3.0    caught     1      v England
# 131    55   63   8   0   87.30  3.0    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# 2    Colombo (RPS)  24-Aug-08
# 3    Colombo (RPS)  27-Aug-08
# ...

# %%
virat['Dismissal'].dropna()
# Out:
# 0          lbw
# 1       caught
# 2      run out
# 3       bowled
# 4          lbw
#         ...
# 127     caught
# 128     caught
# 129     caught
# 130     caught
# 131     caught
# Name: Dismissal, Length: 132, dtype: str

# %%
movies['genre'].dropna()
# Out:
# 0                           Romance
# 1       Adventure | Drama | Musical
# 2                   Action | Comedy
# 3                   Drama | Romance
# 4           Action | Comedy | Drama
#                    ...
# 1277               Comedy | Romance
# 1278                        Mystery
# 1280                         Horror
# 1282                         Comedy
# 1283                       Thriller
# Name: genre, Length: 1282, dtype: str

# %% [markdown]
# ## Fillna Method(for adding values on NaN)

# %%
movies['genre'].fillna('jobayer')
# Out:
# 0                           Romance
# 1       Adventure | Drama | Musical
# 2                   Action | Comedy
# 3                   Drama | Romance
# 4           Action | Comedy | Drama
#                    ...
# 1279                        jobayer
# 1280                         Horror
# 1281                        jobayer
# 1282                         Comedy
# 1283                       Thriller
# Name: genre, Length: 1284, dtype: str

# %%
dupp= pd.DataFrame(
    {
        'name': ['jobayer', 'hossen', 'joy', 'hossen'],
        'number': ['30', '35', '44', '35']
    }
)
dupp
# Out:
#       name number
# 0  jobayer     30
# 1   hossen     35
# 2      joy     44
# 3   hossen     35

# %%
dupp.duplicated().sum()
# Out:
# np.int64(1)

# %%
dupp[dupp.duplicated()]
# Out:
#      name number
# 3  hossen     35

# %% [markdown]
# ## isnull Method

# %%
[movies['genre'].isnull()]
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1279     True
#  1280    False
#  1281     True
#  1282    False
#  1283    False
#  Name: genre, Length: 1284, dtype: bool]

# %%
movies['genre'][movies['genre'].isnull()]
# Out:
# 1279    NaN
# 1281    NaN
# Name: genre, dtype: str

# %% [markdown]
# ## notnull Method

# %%
[movies['genre'].notnull()]
# Out:
# [0        True
#  1        True
#  2        True
#  3        True
#  4        True
#          ...
#  1279    False
#  1280     True
#  1281    False
#  1282     True
#  1283     True
#  Name: genre, Length: 1284, dtype: bool]

# %%
movies.notnull()
# Out:
#       imdbId  title  releaseYear  releaseDate  genre  writers  actors  \
# 0       True   True         True         True   True     True    True
# 1       True   True         True         True   True     True    True
# 2       True   True         True         True   True    False    True
# 3       True   True         True         True   True     True    True
# 4       True   True         True         True   True     True    True
# ...      ...    ...          ...          ...    ...      ...     ...
# 1279    True   True         True         True  False     True    True
# 1280    True   True         True         True   True    False    True
# 1281    True   True         True         True  False     True    True
# 1282    True   True         True         True   True    False    True
# 1283    True   True         True         True   True     True    True
#
#       directors  sequel  hitFlop
# 0          True    True     True
# 1          True    True     True
# ...

# %% [markdown]
# ## sort index

# %%
marks= {
    'math': 67 ,
    'physics': 55,
    'chemistry': 76,
    'biology': 60
}
marks_series= pd.Series(marks)
marks_series
# Out:
# math         67
# physics      55
# chemistry    76
# biology      60
# dtype: int64

# %%
marks_series.sort_index()
# Out:
# biology      60
# chemistry    76
# math         67
# physics      55
# dtype: int64

# %%
movies.sort_index(ascending= False)
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 1283  tt4228746                                Zid         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# ...         ...                                ...          ...          ...
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 0     tt0118578                             Albela         2001  20 Apr 2001
#
#                             genre  \
# ...

# %% [markdown]
# ## set index(dataframe)

# %%
virat
# Out:
#      Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0      12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 1      37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 2      25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 3      54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 4      31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ..    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127    45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 128    65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 129   122  105   8   5  116.19  3.0    caught     2      v England
# 130     8    5   2   0  160.00  3.0    caught     1      v England
# 131    55   63   8   0   87.30  3.0    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# 2    Colombo (RPS)  24-Aug-08
# 3    Colombo (RPS)  27-Aug-08
# ...

# %%
virat.set_index('Start Date', inplace= True)

# %%
virat
# Out:
#             Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# Start Date
# 18-Aug-08     12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 20-Aug-08     37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 24-Aug-08     25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 27-Aug-08     54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 29-Aug-08     31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ...          ...  ...  ..  ..     ...  ...       ...   ...            ...
# 26-Oct-16     45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 29-Oct-16     65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 15-Jan-17    122  105   8   5  116.19  3.0    caught     2      v England
# 19-Jan-17      8    5   2   0  160.00  3.0    caught     1      v England
# 22-Jan-17     55   63   8   0   87.30  3.0    caught     2      v England
#
#                    Ground
# Start Date
# 18-Aug-08        Dambulla
# ...

# %% [markdown]
# ## reset index

# %%
virat.reset_index(inplace= True)

# %%
virat
# Out:
#     Start Date  Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0    18-Aug-08    12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 1    20-Aug-08    37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 2    24-Aug-08    25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 3    27-Aug-08    54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 4    29-Aug-08    31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ..         ...   ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127  26-Oct-16    45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 128  29-Oct-16    65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 129  15-Jan-17   122  105   8   5  116.19  3.0    caught     2      v England
# 130  19-Jan-17     8    5   2   0  160.00  3.0    caught     1      v England
# 131  22-Jan-17    55   63   8   0   87.30  3.0    caught     2      v England
#
#             Ground
# ...

# %%
virat.set_index()
# Out:
#     Start Date  Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0    18-Aug-08    12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 1    20-Aug-08    37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 2    24-Aug-08    25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 3    27-Aug-08    54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 4    29-Aug-08    31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ..         ...   ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127  26-Oct-16    45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 128  29-Oct-16    65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 129  15-Jan-17   122  105   8   5  116.19  3.0    caught     2      v England
# 130  19-Jan-17     8    5   2   0  160.00  3.0    caught     1      v England
# 131  22-Jan-17    55   63   8   0   87.30  3.0    caught     2      v England
#
#             Ground
# ...

# %%
virat
# Out:
#             Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# Start Date
# 18-Aug-08     12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 20-Aug-08     37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 24-Aug-08     25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 27-Aug-08     54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 29-Aug-08     31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ...          ...  ...  ..  ..     ...  ...       ...   ...            ...
# 26-Oct-16     45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 29-Oct-16     65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 15-Jan-17    122  105   8   5  116.19  3.0    caught     2      v England
# 19-Jan-17      8    5   2   0  160.00  3.0    caught     1      v England
# 22-Jan-17     55   63   8   0   87.30  3.0    caught     2      v England
#
#                    Ground
# Start Date
# 18-Aug-08        Dambulla
# ...

# %%
virat.reset_index().set_index('Opposition')
# Out:
#               Start Date  Runs   BF  4s  6s      SR  Pos Dismissal  Inns  \
# Opposition
# v Sri Lanka    18-Aug-08    12   22   1   0   54.54  2.0       lbw     1
# v Sri Lanka    20-Aug-08    37   67   6   0   55.22  2.0    caught     2
# v Sri Lanka    24-Aug-08    25   38   4   0   65.78  1.0   run out     1
# v Sri Lanka    27-Aug-08    54   66   7   0   81.81  1.0    bowled     1
# v Sri Lanka    29-Aug-08    31   46   3   1   67.39  1.0       lbw     2
# ...                  ...   ...  ...  ..  ..     ...  ...       ...   ...
# v New Zealand  26-Oct-16    45   51   2   1   88.23  3.0    caught     2
# v New Zealand  29-Oct-16    65   76   2   1   85.52  3.0    caught     1
# v England      15-Jan-17   122  105   8   5  116.19  3.0    caught     2
# v England      19-Jan-17     8    5   2   0  160.00  3.0    caught     1
# v England      22-Jan-17    55   63   8   0   87.30  3.0    caught     2
#
#                       Ground
# Opposition
# v Sri Lanka         Dambulla
# ...

# %%
movies
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
movies.set_index('title', inplace= True)

# %%
movies
# Out:
#                                       imdbId  releaseYear  releaseDate  \
# title
# Albela                             tt0118578         2001  20 Apr 2001
# Lagaan: Once Upon a Time in India  tt0169102         2001  08 May 2002
# Meri Biwi Ka Jawab Nahin           tt0187279         2004  02 Jul 2004
# Hum Tumhare Hain Sanam             tt0222024         2002  24 May 2002
# One 2 Ka 4                         tt0227194         2001  30 Mar 2001
# ...                                      ...          ...          ...
# Shuruaat Ka Interval               tt4121522         2014  15 Aug 2014
# Trip to Bhangarh                   tt4187650         2014  28 Aug 2014
# Zed Plus                           tt4190220         2014  28 Nov 2014
# Gollu aur Pappu                    tt4219300         2014  21 Nov 2014
# Zid                                tt4228746         2014  28 Nov 2014
#
#                                                          genre  \
# title
# ...

# %%
movies.rename(columns= {'writers': 'movie_writers', 'genre': 'movie_genre'})
# Out:
#                                       imdbId  releaseYear  releaseDate  \
# title
# Albela                             tt0118578         2001  20 Apr 2001
# Lagaan: Once Upon a Time in India  tt0169102         2001  08 May 2002
# Meri Biwi Ka Jawab Nahin           tt0187279         2004  02 Jul 2004
# Hum Tumhare Hain Sanam             tt0222024         2002  24 May 2002
# One 2 Ka 4                         tt0227194         2001  30 Mar 2001
# ...                                      ...          ...          ...
# Shuruaat Ka Interval               tt4121522         2014  15 Aug 2014
# Trip to Bhangarh                   tt4187650         2014  28 Aug 2014
# Zed Plus                           tt4190220         2014  28 Nov 2014
# Gollu aur Pappu                    tt4219300         2014  21 Nov 2014
# Zid                                tt4228746         2014  28 Nov 2014
#
#                                                    movie_genre  \
# title
# ...

# %% [markdown]
# ## unique and nunique

# %%
s = pd.Series([1, 2, 2, 3, 3, 3])
s.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
s.nunique()
# Out:
# 3
